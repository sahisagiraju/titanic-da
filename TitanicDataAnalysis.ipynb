# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    pclass  survived                                             name  gender  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'gender', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df[df.columns[3]].unique() # p class, should say 123
# Out:
# array(['female', 'male'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   gender     1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df['age'].isnull() # get the exact rows later
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1309, dtype: bool

# %%
df['age'].isnull().sum() # get the exact rows later
# Out:
# 263

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived', data=df, palette='dark')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='survived', hue='gender', data=df, palette='bright')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='survived', hue='pclass', data=df, palette='icefire')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.displot(df['age'].dropna(), kde=False,color='darkred', bins=30)

# %%
sns.countplot(x='sibsp', data=df) # sidsp = sibling/spouse
# Out:
# <Axes: xlabel='sibsp', ylabel='count'>

# %%
plt.figure(figsize=(8,4))
boxplot = sns.boxplot(x='pclass', y='age', data=df, palette='bright', showmeans=True)
# x = class, y = age. It is against class and age.

# %%
#help(boxplot)

# %%
def impute_age(cols):
    age = cols[0]
    pclass = cols[1]

    if pd.isnull(age):
        if pclass == 1:
            return 39
        elif pclass == 2:
            return 29
        else:
            return 24
    else:
        return age

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
df['age'] = df[['age', 'pclass']].apply(impute_age, axis=1) # age is imputed

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'gender', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
df.tail()
# Out:
#       pclass  survived                       name  gender   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female  24.0      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
gender = pd.get_dummies(df['gender'], drop_first=True).astype(int)
embarked = pd.get_dummies(df['embarked'], drop_first=True).astype(int)

# %%
gender
# Out:
#       male
# 0        0
# 1        1
# 2        0
# 3        1
# 4        0
# ...    ...
# 1304     0
# 1305     0
# 1306     1
# 1307     1
# 1308     1
#
# [1309 rows x 1 columns]

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
embarked
# Out:
#       Q  S
# 0     0  1
# 1     0  1
# 2     0  1
# 3     0  1
# 4     0  1
# ...  .. ..
# 1304  0  0
# 1305  0  0
# 1306  0  0
# 1307  0  0
# 1308  0  1
#
# [1309 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'age', 'sibsp', 'parch', 'embarked'], dtype='object')

# %%
df.drop(['name', 'gender', 'ticket', 'fare', 'cabin', 'boat', 'body', 'home.dest'], inplace = True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-ec1a374db9b5> in <cell line: 1>()
# ----> 1 df.drop(['name', 'gender', 'ticket', 'fare', 'cabin', 'boat', 'body', 'home.dest'], inplace = True, axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['name', 'gender', 'ticket', 'fare', 'cabin', 'boat', 'body', 'home.dest'] not found in axis"

# %%
df.head()
# Out:
#    pclass  survived      age  sibsp  parch embarked
# 0       1         1  29.0000      0      0        S
# 1       1         1   0.9167      1      2        S
# 2       1         0   2.0000      1      2        S
# 3       1         0  30.0000      1      2        S
# 4       1         0  25.0000      1      2        S

# %%
df.drop(['embarked'], inplace = True, axis=1)

# %%
df = pd.concat([df, gender, embarked], axis=1)

# %%
df.head()
# Out:
#    pclass  survived      age  sibsp  parch  male  Q  S
# 0       1         1  29.0000      0      0     0  0  1
# 1       1         1   0.9167      1      2     1  0  1
# 2       1         0   2.0000      1      2     0  0  1
# 3       1         0  30.0000      1      2     1  0  1
# 4       1         0  25.0000      1      2     0  0  1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   int64
#  2   age       1309 non-null   float64
#  3   sibsp     1309 non-null   int64
#  4   parch     1309 non-null   int64
#  5   male      1309 non-null   int64
#  6   Q         1309 non-null   int64
#  7   S         1309 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 81.9 KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   survived  1309 non-null   int64
#  2   age       1309 non-null   float64
#  3   sibsp     1309 non-null   int64
#  4   parch     1309 non-null   int64
#  5   male      1309 non-null   int64
#  6   Q         1309 non-null   int64
#  7   S         1309 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 81.9 KB
